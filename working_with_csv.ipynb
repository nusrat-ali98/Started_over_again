# %%
import csv
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-01fa48c2-a788-4e9e-86ea-81e37517484f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01fa48c2-a788-4e9e-86ea-81e37517484f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = [90,80,26,72,81,43,55]
total = sum(data)
average = total/len(data)
highest_nmb = max(data)
mini_nmb = min(data)
print("Total: ",total)
print(f"Average: {average:.2f}")
print("Highest number: ",highest_nmb)
print("Lowest number: ",mini_nmb)
# Out:
# Total:  447
# Average: 63.86
# Highest number:  90
# Lowest number:  26

# %%
with open("simple_data.csv", "r") as file:
  reader = csv.reader(file)
  for line in reader:
    print(line)
# Out:
# ['name', 'course', 'city', 'score']
# ['Ananya Sharma', 'Analytics', 'Pune', '82']
# ['Rohan Verma', 'Analytics', 'Delhi', '67']
# ['Simran Kaur', 'Design', 'Mumbai', '91']
# ['Arjun Mehta', 'Analytics', 'Pune', '48']

# %%
with open("simple_data.csv", "r") as file:
  reader = csv.reader(file)
  next(reader)
  for row in reader:
    print("___ " + row[1] + " ___ ")
# Out:
# ___ Analytics ___
# ___ Analytics ___
# ___ Design ___
# ___ Analytics ___

# %%
with open("simple_data.csv", "r") as file:
  reader =  csv.DictReader(file)
  for row in reader:
    print(row["name"] , "Score", row["score"] )
# Out:
# Ananya Sharma Score 82
# Rohan Verma Score 67
# Simran Kaur Score 91
# Arjun Mehta Score 48

# %%
students = [
    {"name": "Nusrat Ali", "course": "Data Science", "score" : 94},
    {"name": "Ahmad Ali", "course": "Data Science", "score" : 83}
            ]

# %%
with open("students.csv", "w", newline="") as file:
  fieldnames = ["name", "course","score"]
  writer = csv.DictWriter(file, fieldnames=fieldnames)
  writer.writeheader()
  writer.writerows(students)
